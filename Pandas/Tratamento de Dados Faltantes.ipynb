# %% [markdown]
# # Relatório de Análise V
# ## Tratamento de dados faltantes
# ### Preparando o ambiente

# %%
import pandas as pd

# %%
alugueis_residenciais = pd.read_csv('dados/alugueis_residenciais.csv', sep = ';')
alugueis_residenciais.sample(10)
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 6949          Apartamento  Recreio dos Bandeirantes        3      2       0
# 6087          Apartamento                   Estácio        2      1       0
# 13502           Quitinete                    Leblon        1      0       0
# 3248          Apartamento                  Cachambi        1      1       0
# 3184          Apartamento                     Méier        3      0       0
# 18442         Apartamento                Copacabana        3      1       0
# 22908  Casa de Condomínio                Copacabana        2      1       1
# 3493          Apartamento           Barra da Tijuca        3      3       1
# 4640          Apartamento                     Méier        2      0       0
# 19113         Apartamento                Portuguesa        2      1       0
#
#        Area    Valor  Condominio   IPTU
# 6949    133   2190.0      1004.0    NaN
# 6087     72   1300.0       790.0    NaN
# 13502    26   2800.0       600.0   30.0
# 3248     48    750.0       250.0    NaN
# 3184    100   1500.0       100.0    NaN
# 18442   140   3700.0      1350.0  329.0
# 22908    80   3000.0        50.0    NaN
# 3493    230  16500.0         NaN    NaN
# 4640     92   1400.0       520.0  123.0
# 19113    48   1000.0       337.0    NaN

# %% [markdown]
# ### Executando o tratamento de dados

# %%
# Retorna um DataFrame booleano para cada valor, se é nulo ou não
alugueis_residenciais.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 23102  False   False    False  False   False  False  False       False  False
# 23103  False   False    False  False   False  False  False       False  False
# 23104  False   False    False  False   False  False  False       False  False
# 23105  False   False    False  False   False  False  False       False  False
# 23106  False   False    False  False   False  False  False       False   True
#
# [23107 rows x 9 columns]

# %%
# Retorna um DataFrame inverso do anterior
alugueis_residenciais.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 23102  True    True     True   True    True  True   True        True   True
# 23103  True    True     True   True    True  True   True        True   True
# 23104  True    True     True   True    True  True   True        True   True
# 23105  True    True     True   True    True  True   True        True   True
# 23106  True    True     True   True    True  True   True        True  False
#
# [23107 rows x 9 columns]

# %%
# Registros totais vs Registros não-nulos
alugueis_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23107 entries, 0 to 23106
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        23107 non-null  object
#  1   Bairro      23107 non-null  object
#  2   Quartos     23107 non-null  int64
#  3   Vagas       23107 non-null  int64
#  4   Suites      23107 non-null  int64
#  5   Area        23107 non-null  int64
#  6   Valor       23098 non-null  float64
#  7   Condominio  21244 non-null  float64
#  8   IPTU        16228 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
ar_valor_nulo = alugueis_residenciais[alugueis_residenciais.Valor.isnull()]
ar_valor_nulo
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 60    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1524  Apartamento             Leme        2      0       0    75    NaN
# 1718         Casa     Campo Grande        3      4       3   363    NaN
# 2055  Apartamento         Botafogo        2      0       0    95    NaN
# 2077  Apartamento       Copacabana        2      0       0    72    NaN
# 5059         Casa     Campo Grande        3      2       1   100    NaN
# 8777  Apartamento             Leme        2      0       1    75    NaN
# 9166  Apartamento           Glória        3      0       1   135    NaN
# 9371  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 60         970.0   68.0
# 1524       878.0    NaN
# 1718         NaN    NaN
# 2055      1010.0  170.0
# 2077       850.0    NaN
# 5059         NaN    NaN
# 8777       878.0    NaN
# 9166       910.0  228.0
# 9371       880.0  221.0

# %%
# No caso da coluna valor, os registros sem esta coluna preenchida não são válidos para nosso conjunto de dados
shape_inicial = alugueis_residenciais.shape[0]
alugueis_residenciais.dropna(subset = ['Valor'], inplace = True)
shape_final = alugueis_residenciais.shape[0]

print(f'Valores removidos: {shape_inicial - shape_final}')
# Out:
# Valores removidos: 9

# %%
# Não retorna mais dados
ar_valor_nulo = alugueis_residenciais[alugueis_residenciais.Valor.isnull()]
ar_valor_nulo
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ### Tratamento condicional

# %%
alugueis_residenciais[alugueis_residenciais['Condominio'].isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 6      Casa de Condomínio           Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                     Ramos        2      2       0
# 8             Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 23037                Casa              Campo Grande        1      0       0
# 23043        Casa de Vila                    Pavuna        2      0       0
# 23062                Casa  Recreio dos Bandeirantes        4      2       2
# 23074                Casa             Bento Ribeiro        2      1       0
# 23085                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# 1       100   7000.0         NaN   NaN
# 4        70   1200.0         NaN   NaN
# 6       750  22000.0         NaN   NaN
# 7        65   1000.0         NaN   NaN
# 8        36   1200.0         NaN   NaN
# ...     ...      ...         ...   ...
# 23037    50    600.0         NaN   NaN
# 23043    55    600.0         NaN   NaN
# 23062   352   6500.0         NaN   NaN
# 23074    60   1400.0         NaN   NaN
# 23085   160   5000.0         NaN  80.0
#
# [1861 rows x 9 columns]

# %%
ar_valor_nulo = alugueis_residenciais[alugueis_residenciais.Condominio.isnull()]
ar_valor_nulo
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 6      Casa de Condomínio           Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                     Ramos        2      2       0
# 8             Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 23037                Casa              Campo Grande        1      0       0
# 23043        Casa de Vila                    Pavuna        2      0       0
# 23062                Casa  Recreio dos Bandeirantes        4      2       2
# 23074                Casa             Bento Ribeiro        2      1       0
# 23085                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# 1       100   7000.0         NaN   NaN
# 4        70   1200.0         NaN   NaN
# 6       750  22000.0         NaN   NaN
# 7        65   1000.0         NaN   NaN
# 8        36   1200.0         NaN   NaN
# ...     ...      ...         ...   ...
# 23037    50    600.0         NaN   NaN
# 23043    55    600.0         NaN   NaN
# 23062   352   6500.0         NaN   NaN
# 23074    60   1400.0         NaN   NaN
# 23085   160   5000.0         NaN  80.0
#
# [1861 rows x 9 columns]

# %%
# Alugueis de apartamento com condomínios nulos também devem ser descartados
com_condominio = ["Apartamento", "Casa de Condomínio"]
selecao = (alugueis_residenciais.Tipo.isin(com_condominio)) & (alugueis_residenciais.Condominio.isnull())
alugueis_residenciais[selecao]
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 4             Apartamento     Vista Alegre        3      1       0    70
# 6      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7      Casa de Condomínio            Ramos        2      2       0    65
# 8             Apartamento           Centro        1      0       0    36
# 15     Casa de Condomínio          Taquara        3      1       1   115
# ...                   ...              ...      ...    ...     ...   ...
# 22852         Apartamento       Copacabana        3      0       0   130
# 22881         Apartamento        Guadalupe        1      0       0    40
# 22898         Apartamento       Bonsucesso        1      0       0    60
# 22928         Apartamento         Flamengo        2      0       0    59
# 23000         Apartamento        Cascadura        3      0       1    70
#
#          Valor  Condominio  IPTU
# 4       1200.0         NaN   NaN
# 6      22000.0         NaN   NaN
# 7       1000.0         NaN   NaN
# 8       1200.0         NaN   NaN
# 15      2000.0         NaN   NaN
# ...        ...         ...   ...
# 22852   4600.0         NaN   NaN
# 22881    550.0         NaN   NaN
# 22898   1000.0         NaN   NaN
# 22928   3500.0         NaN   NaN
# 23000   1200.0         NaN   NaN
#
# [840 rows x 9 columns]

# %%
shape_inicial = alugueis_residenciais.shape[0]
#Inverte a seleção
alugueis_residenciais  = alugueis_residenciais[~selecao]
shape_final = alugueis_residenciais.shape[0]

print(f'Valores removidos: {shape_inicial - shape_final}')
# Out:
# Valores removidos: 840

# %%
alugueis_residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 23102  Apartamento                 Méier        2      0       0    70
# 23103    Quitinete                Centro        0      0       0    27
# 23104  Apartamento           Jacarepaguá        3      1       2    78
# 23105  Apartamento  São Francisco Xavier        2      1       0    48
# 23106  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# 5      1300.0       301.0  17.0
# ...       ...         ...   ...
# 23102   900.0       490.0  48.0
# 23103   800.0       350.0  25.0
# 23104  1800.0       800.0  40.0
# 23105  1400.0       509.0  37.0
# 23106  3000.0       760.0   NaN
#
# [22258 rows x 9 columns]

# %%
alugueis_residenciais.IPTU.fillna(0, inplace = True)
alugueis_residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 23102  Apartamento                 Méier        2      0       0    70
# 23103    Quitinete                Centro        0      0       0    27
# 23104  Apartamento           Jacarepaguá        3      1       2    78
# 23105  Apartamento  São Francisco Xavier        2      1       0    48
# 23106  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 5      1300.0       301.0  17.0
# ...       ...         ...   ...
# 23102   900.0       490.0  48.0
# 23103   800.0       350.0  25.0
# 23104  1800.0       800.0  40.0
# 23105  1400.0       509.0  37.0
# 23106  3000.0       760.0   0.0
#
# [22258 rows x 9 columns]

# %%
alugueis_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22258 entries, 0 to 23106
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22258 non-null  object
#  1   Bairro      22258 non-null  object
#  2   Quartos     22258 non-null  int64
#  3   Vagas       22258 non-null  int64
#  4   Suites      22258 non-null  int64
#  5   Area        22258 non-null  int64
#  6   Valor       22258 non-null  float64
#  7   Condominio  21237 non-null  float64
#  8   IPTU        22258 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
# Condomínios nulos são os que não são de imóveis de condomínio. Tratando, então:
alugueis_residenciais.Condominio.fillna(0, inplace = True)
alugueis_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22258 entries, 0 to 23106
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22258 non-null  object
#  1   Bairro      22258 non-null  object
#  2   Quartos     22258 non-null  int64
#  3   Vagas       22258 non-null  int64
#  4   Suites      22258 non-null  int64
#  5   Area        22258 non-null  int64
#  6   Valor       22258 non-null  float64
#  7   Condominio  22258 non-null  float64
#  8   IPTU        22258 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Exportando os dados

# %%
alugueis_residenciais.to_csv('dados/alugueis_residenciais_filtrados.csv', sep = ';', index = False)
